# %% [markdown]
# # Translate Notebooks
#
# This preprocesses all the ipython notebooks over to rst files so that sphinx can import them.

# %%
import glob
import os.path

# %%
notebooks = glob.glob('source/analyses/*/*.ipynb')
notebooks += glob.glob('source/data/*/*.ipynb')
notebooks
# Out:
# ['source/analyses/data_handling/exogenous_timeseries.ipynb',
#  'source/analyses/data_handling/exogenous_timeseries_Workbook.ipynb',
#  'source/analyses/data_handling/pandas.ipynb',
#  'source/analyses/data_handling/pandas_Workbook.ipynb',
#  'source/analyses/data_handling/Writing_to_Database.ipynb',
#  'source/analyses/design_policy/PySD EMA Connector Demo.ipynb',
#  'source/analyses/fitting/Fitting_with_Optimization-Copy1.ipynb',
#  'source/analyses/fitting/Fitting_with_Optimization.ipynb',
#  'source/analyses/fitting/Fitting_with_Optimization_Workbook.ipynb',
#  'source/analyses/fitting/Massively_Parallel_Fitting.ipynb',
#  'source/analyses/fitting/MCMC_for_fitting_models.ipynb',
#  'source/analyses/fitting/MCMC_for_fitting_models_Workbook.ipynb',
#  'source/analyses/fitting/Penny_Jar.ipynb',
#  'source/analyses/fitting/Step_at_a_time_optimization.ipynb',
#  'source/analyses/fitting/Step_at_a_time_optimization_Workbook.ipynb',
#  'source/analyses/geo/Doing_more_with_spatialdata_multi_regional_SIR_Model.ipynb',
#  'source/analyses/geo/Exploring_models_across_geographic_scales.ipynb',
#  'source/analyses/getting_started/Git_and_Github.ipynb',
#  'source/analyses/getting_started/Hello_World_Teacup.ipynb',
#  'source/analyses/getting_started/Hello_World_Teacup_Workbook.ipynb',
#  'source/analyses/getting_started/Installing.ipynb',
#  'source/analyses/getting_started/Introduction.ipynb',
#  'source/analyses/getting_started/Notebook.ipynb',
#  'source/analyses/getting_started/PySD_Challenge_1.ipynb',
#  'source/analyses/getting_started/PySD_Challenge_1_Workbook.ipynb',
#  'source/analyses/getting_started/Python.ipynb',
#  'source/analyses/getting_started/Python_Workbook.ipynb',
#  'source/analyses/getting_started/Untitled.ipynb',
#  'source/analyses/model_comparison/Comparing_Models.ipynb',
#  'source/analyses/model_comparison/Designing_Experiments.ipynb',
#  'source/analyses/realtime/Nth_Order_Delay_Demo.ipynb',
#  'source/analyses/realtime/Twitter_Stream.ipynb',
#  'source/analyses/sensitivity/Latin_Hypercube_Sampling.ipynb',
#  'source/analyses/surrogating_functions/Surrogating_with_regression.ipynb',
#  'source/analyses/surrogating_functions/Surrogating_with_regression_Workbook.ipynb',
#  'source/analyses/Testing/Testing_Behavior-Copy1.ipynb',
#  'source/analyses/Testing/Testing_Behavior.ipynb',
#  'source/analyses/Testing/Untitled.ipynb',
#  'source/analyses/visualization/delete_me.ipynb',
#  'source/analyses/visualization/Marginal Density Plot - Interactive.ipynb',
#  'source/analyses/visualization/Marginal Density Plot.ipynb',
#  'source/analyses/visualization/matplotlib.ipynb',
#  'source/analyses/visualization/matplotlib_Workbook.ipynb',
#  'source/analyses/visualization/other_visualization_libraries.ipynb',
#  'source/analyses/visualization/phase_portraits.ipynb',
#  'source/analyses/visualization/plotting_suite_of_simulations.ipynb',
#  'source/analyses/workflow/Unit_Testing.ipynb',
#  'source/analyses/wrapper_EMAWorkbench/Minimal Example PySD with EMA.ipynb',
#  'source/data/Baby_Names/Baby_Name_Data.ipynb',
#  'source/data/Census/US_Census_Data_Collection.ipynb',
#  'source/data/Climate/sources.ipynb',
#  'source/data/Defects_Synthetic/Manufacturing_Defects_Synthetic.ipynb',
#  'source/data/Ebola/Ebola_Data_Loader.ipynb',
#  'source/data/Emails/Email_Data_Formatter.ipynb',
#  'source/data/MA_Towns/Town_Formatter.ipynb',
#  'source/data/SD_Fever/Prepare Data.ipynb']

# %%
for infile in notebooks:
    infile = infile.replace(' ','\ ')
    
    #convert notebook in its local directory
    path, nbfile = os.path.split(infile)    
    ! cd $path; ipython nbconvert --to rst $nbfile

    #move the .rst file
    no_ext = os.path.splitext(nbfile)[0]
    movefiles = path+'/'+no_ext+'.rst'
    dest = 'docs/'+'/'.join(path.split('/')[1:]) #pretty dependent on directory structure
    ! mv $movefiles $dest

    #move supporting files, if there are any
    movedir = path+'/'+no_ext+'_files'
    if os.path.exists(movedir):
        destdir = 'docs/'+'/'.join(path.split('/')[1:])+'/'+no_ext+'_files'        
        if os.path.exists(destdir): #check to see if the 'files' directory has already been created
            # !rm -r $destdir #if so, remove it, so we can have a clean slate...
        # !mv $movedir $dest
        
    print '\n'
# Out:
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook exogenous_timeseries.ipynb to rst
# [NbConvertApp] Support files will be in exogenous_timeseries_files/
# [NbConvertApp] Making directory exogenous_timeseries_files
# [NbConvertApp] Writing 6418 bytes to exogenous_timeseries.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook exogenous_timeseries_Workbook.ipynb to rst
# [NbConvertApp] Support files will be in exogenous_timeseries_Workbook_files/
# [NbConvertApp] Making directory exogenous_timeseries_Workbook_files
# [NbConvertApp] Writing 7317 bytes to exogenous_timeseries_Workbook.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook pandas.ipynb to rst
# [NbConvertApp] Writing 32136 bytes to pandas.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook pandas_Workbook.ipynb to rst
# [NbConvertApp] Writing 7315 bytes to pandas_Workbook.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Writing_to_Database.ipynb to rst
# [NbConvertApp] Writing 3438 bytes to Writing_to_Database.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook PySD EMA Connector Demo.ipynb to rst
# [NbConvertApp] Support files will be in PySD EMA Connector Demo_files/
# [NbConvertApp] Making directory PySD EMA Connector Demo_files
# [NbConvertApp] Writing 1452 bytes to PySD EMA Connector Demo.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Fitting_with_Optimization-Copy1.ipynb to rst
# [NbConvertApp] Support files will be in Fitting_with_Optimization-Copy1_files/
# [NbConvertApp] Making directory Fitting_with_Optimization-Copy1_files
# [NbConvertApp] Making directory Fitting_with_Optimization-Copy1_files
# [NbConvertApp] Writing 7461 bytes to Fitting_with_Optimization-Copy1.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Fitting_with_Optimization.ipynb to rst
# [NbConvertApp] Support files will be in Fitting_with_Optimization_files/
# [NbConvertApp] Making directory Fitting_with_Optimization_files
# [NbConvertApp] Making directory Fitting_with_Optimization_files
# [NbConvertApp] Writing 7402 bytes to Fitting_with_Optimization.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Fitting_with_Optimization_Workbook.ipynb to rst
# [NbConvertApp] Support files will be in Fitting_with_Optimization_Workbook_files/
# [NbConvertApp] Making directory Fitting_with_Optimization_Workbook_files
# [NbConvertApp] Making directory Fitting_with_Optimization_Workbook_files
# [NbConvertApp] Writing 6716 bytes to Fitting_with_Optimization_Workbook.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Massively_Parallel_Fitting.ipynb to rst
# [NbConvertApp] Support files will be in Massively_Parallel_Fitting_files/
# [NbConvertApp] Making directory Massively_Parallel_Fitting_files
# [NbConvertApp] Writing 8458 bytes to Massively_Parallel_Fitting.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook MCMC_for_fitting_models.ipynb to rst
# [NbConvertApp] Support files will be in MCMC_for_fitting_models_files/
# [NbConvertApp] Making directory MCMC_for_fitting_models_files
# [NbConvertApp] Making directory MCMC_for_fitting_models_files
# [NbConvertApp] Making directory MCMC_for_fitting_models_files
# [NbConvertApp] Making directory MCMC_for_fitting_models_files
# [NbConvertApp] Making directory MCMC_for_fitting_models_files
# [NbConvertApp] Writing 8942 bytes to MCMC_for_fitting_models.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook MCMC_for_fitting_models_Workbook.ipynb to rst
# [NbConvertApp] Support files will be in MCMC_for_fitting_models_Workbook_files/
# [NbConvertApp] Making directory MCMC_for_fitting_models_Workbook_files
# [NbConvertApp] Making directory MCMC_for_fitting_models_Workbook_files
# [NbConvertApp] Making directory MCMC_for_fitting_models_Workbook_files
# [NbConvertApp] Making directory MCMC_for_fitting_models_Workbook_files
# [NbConvertApp] Making directory MCMC_for_fitting_models_Workbook_files
# [NbConvertApp] Writing 8960 bytes to MCMC_for_fitting_models_Workbook.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Penny_Jar.ipynb to rst
# [NbConvertApp] Support files will be in Penny_Jar_files/
# [NbConvertApp] Making directory Penny_Jar_files
# [NbConvertApp] Making directory Penny_Jar_files
# [NbConvertApp] Making directory Penny_Jar_files
# [NbConvertApp] Making directory Penny_Jar_files
# [NbConvertApp] Writing 19375 bytes to Penny_Jar.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Step_at_a_time_optimization.ipynb to rst
# [NbConvertApp] Support files will be in Step_at_a_time_optimization_files/
# [NbConvertApp] Making directory Step_at_a_time_optimization_files
# [NbConvertApp] Making directory Step_at_a_time_optimization_files
# [NbConvertApp] Writing 8140 bytes to Step_at_a_time_optimization.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Step_at_a_time_optimization_Workbook.ipynb to rst
# [NbConvertApp] Support files will be in Step_at_a_time_optimization_Workbook_files/
# [NbConvertApp] Making directory Step_at_a_time_optimization_Workbook_files
# [NbConvertApp] Making directory Step_at_a_time_optimization_Workbook_files
# [NbConvertApp] Writing 8186 bytes to Step_at_a_time_optimization_Workbook.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Doing_more_with_spatialdata_multi_regional_SIR_Model.ipynb to rst
# [NbConvertApp] Support files will be in Doing_more_with_spatialdata_multi_regional_SIR_Model_files/
# [NbConvertApp] Making directory Doing_more_with_spatialdata_multi_regional_SIR_Model_files
# [NbConvertApp] Making directory Doing_more_with_spatialdata_multi_regional_SIR_Model_files
# [NbConvertApp] Making directory Doing_more_with_spatialdata_multi_regional_SIR_Model_files
# [NbConvertApp] Making directory Doing_more_with_spatialdata_multi_regional_SIR_Model_files
# [NbConvertApp] Making directory Doing_more_with_spatialdata_multi_regional_SIR_Model_files
# [NbConvertApp] Making directory Doing_more_with_spatialdata_multi_regional_SIR_Model_files
# [NbConvertApp] Making directory Doing_more_with_spatialdata_multi_regional_SIR_Model_files
# [NbConvertApp] Making directory Doing_more_with_spatialdata_multi_regional_SIR_Model_files
# [NbConvertApp] Writing 36378 bytes to Doing_more_with_spatialdata_multi_regional_SIR_Model.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Exploring_models_across_geographic_scales.ipynb to rst
# [NbConvertApp] Support files will be in Exploring_models_across_geographic_scales_files/
# [NbConvertApp] Making directory Exploring_models_across_geographic_scales_files
# [NbConvertApp] Making directory Exploring_models_across_geographic_scales_files
# [NbConvertApp] Making directory Exploring_models_across_geographic_scales_files
# [NbConvertApp] Making directory Exploring_models_across_geographic_scales_files
# [NbConvertApp] Making directory Exploring_models_across_geographic_scales_files
# [NbConvertApp] Making directory Exploring_models_across_geographic_scales_files
# [NbConvertApp] Writing 38195 bytes to Exploring_models_across_geographic_scales.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Git_and_Github.ipynb to rst
# [NbConvertApp] Writing 1547 bytes to Git_and_Github.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Hello_World_Teacup.ipynb to rst
# [NbConvertApp] Support files will be in Hello_World_Teacup_files/
# [NbConvertApp] Making directory Hello_World_Teacup_files
# [NbConvertApp] Making directory Hello_World_Teacup_files
# [NbConvertApp] Making directory Hello_World_Teacup_files
# [NbConvertApp] Making directory Hello_World_Teacup_files
# [NbConvertApp] Making directory Hello_World_Teacup_files
# [NbConvertApp] Making directory Hello_World_Teacup_files
# [NbConvertApp] Making directory Hello_World_Teacup_files
# [NbConvertApp] Writing 11010 bytes to Hello_World_Teacup.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Hello_World_Teacup_Workbook.ipynb to rst
# [NbConvertApp] Writing 5603 bytes to Hello_World_Teacup_Workbook.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Installing.ipynb to rst
# [NbConvertApp] Writing 2447 bytes to Installing.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Introduction.ipynb to rst
# [NbConvertApp] Writing 2045 bytes to Introduction.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Notebook.ipynb to rst
# [NbConvertApp] Writing 2767 bytes to Notebook.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook PySD_Challenge_1.ipynb to rst
# [NbConvertApp] Support files will be in PySD_Challenge_1_files/
# [NbConvertApp] Making directory PySD_Challenge_1_files
# [NbConvertApp] Making directory PySD_Challenge_1_files
# [NbConvertApp] Writing 7724 bytes to PySD_Challenge_1.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook PySD_Challenge_1_Workbook.ipynb to rst
# [NbConvertApp] Writing 6277 bytes to PySD_Challenge_1_Workbook.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Python.ipynb to rst
# [NbConvertApp] Writing 8773 bytes to Python.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Python_Workbook.ipynb to rst
# [NbConvertApp] Writing 8657 bytes to Python_Workbook.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Untitled.ipynb to rst
# [NbConvertApp] Writing 280 bytes to Untitled.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Comparing_Models.ipynb to rst
# [NbConvertApp] Support files will be in Comparing_Models_files/
# [NbConvertApp] Making directory Comparing_Models_files
# [NbConvertApp] Making directory Comparing_Models_files
# [NbConvertApp] Making directory Comparing_Models_files
# [NbConvertApp] Writing 6717 bytes to Comparing_Models.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Designing_Experiments.ipynb to rst
# [NbConvertApp] Support files will be in Designing_Experiments_files/
# [NbConvertApp] Making directory Designing_Experiments_files
# [NbConvertApp] Making directory Designing_Experiments_files
# [NbConvertApp] Making directory Designing_Experiments_files
# [NbConvertApp] Making directory Designing_Experiments_files
# [NbConvertApp] Making directory Designing_Experiments_files
# [NbConvertApp] Making directory Designing_Experiments_files
# [NbConvertApp] Making directory Designing_Experiments_files
# [NbConvertApp] Writing 8926 bytes to Designing_Experiments.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Nth_Order_Delay_Demo.ipynb to rst
# [NbConvertApp] Writing 5746 bytes to Nth_Order_Delay_Demo.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Twitter_Stream.ipynb to rst
# [NbConvertApp] Writing 8696 bytes to Twitter_Stream.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Latin_Hypercube_Sampling.ipynb to rst
# [NbConvertApp] Writing 10443 bytes to Latin_Hypercube_Sampling.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Surrogating_with_regression.ipynb to rst
# [NbConvertApp] Support files will be in Surrogating_with_regression_files/
# [NbConvertApp] Making directory Surrogating_with_regression_files
# [NbConvertApp] Making directory Surrogating_with_regression_files
# [NbConvertApp] Writing 3816 bytes to Surrogating_with_regression.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Surrogating_with_regression_Workbook.ipynb to rst
# [NbConvertApp] Writing 1871 bytes to Surrogating_with_regression_Workbook.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Testing_Behavior-Copy1.ipynb to rst
# [NbConvertApp] Support files will be in Testing_Behavior-Copy1_files/
# [NbConvertApp] Making directory Testing_Behavior-Copy1_files
# [NbConvertApp] Writing 10616 bytes to Testing_Behavior-Copy1.rst
# mv: rename source/analyses/Testing/Testing_Behavior-Copy1_files to docs/analyses/Testing: Not a directory
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Testing_Behavior.ipynb to rst
# [NbConvertApp] Support files will be in Testing_Behavior_files/
# [NbConvertApp] Making directory Testing_Behavior_files
# [NbConvertApp] Writing 10604 bytes to Testing_Behavior.rst
# mv: rename source/analyses/Testing/Testing_Behavior_files to docs/analyses/Testing: Not a directory
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Untitled.ipynb to rst
# [NbConvertApp] Writing 2256 bytes to Untitled.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook delete_me.ipynb to rst
# [NbConvertApp] Support files will be in delete_me_files/
# [NbConvertApp] Making directory delete_me_files
# [NbConvertApp] Making directory delete_me_files
# [NbConvertApp] Writing 34932 bytes to delete_me.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Marginal Density Plot - Interactive.ipynb to rst
# [NbConvertApp] Support files will be in Marginal Density Plot - Interactive_files/
# [NbConvertApp] Making directory Marginal Density Plot - Interactive_files
# [NbConvertApp] Making directory Marginal Density Plot - Interactive_files
# [NbConvertApp] Making directory Marginal Density Plot - Interactive_files
# [NbConvertApp] Writing 86775 bytes to Marginal Density Plot - Interactive.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Marginal Density Plot.ipynb to rst
# [NbConvertApp] Support files will be in Marginal Density Plot_files/
# [NbConvertApp] Making directory Marginal Density Plot_files
# [NbConvertApp] Writing 7964 bytes to Marginal Density Plot.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook matplotlib.ipynb to rst
# [NbConvertApp] Support files will be in matplotlib_files/
# [NbConvertApp] Making directory matplotlib_files
# [NbConvertApp] Making directory matplotlib_files
# [NbConvertApp] Making directory matplotlib_files
# [NbConvertApp] Making directory matplotlib_files
# [NbConvertApp] Making directory matplotlib_files
# [NbConvertApp] Making directory matplotlib_files
# [NbConvertApp] Making directory matplotlib_files
# [NbConvertApp] Making directory matplotlib_files
# [NbConvertApp] Making directory matplotlib_files
# [NbConvertApp] Making directory matplotlib_files
# [NbConvertApp] Making directory matplotlib_files
# [NbConvertApp] Making directory matplotlib_files
# [NbConvertApp] Writing 9390 bytes to matplotlib.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook matplotlib_Workbook.ipynb to rst
# [NbConvertApp] Writing 6426 bytes to matplotlib_Workbook.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook other_visualization_libraries.ipynb to rst
# [NbConvertApp] Support files will be in other_visualization_libraries_files/
# [NbConvertApp] Making directory other_visualization_libraries_files
# [NbConvertApp] Writing 409116 bytes to other_visualization_libraries.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook phase_portraits.ipynb to rst
# [NbConvertApp] Support files will be in phase_portraits_files/
# [NbConvertApp] Making directory phase_portraits_files
# [NbConvertApp] Writing 4746 bytes to phase_portraits.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook plotting_suite_of_simulations.ipynb to rst
# [NbConvertApp] Support files will be in plotting_suite_of_simulations_files/
# [NbConvertApp] Making directory plotting_suite_of_simulations_files
# [NbConvertApp] Making directory plotting_suite_of_simulations_files
# [NbConvertApp] Writing 10757 bytes to plotting_suite_of_simulations.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Unit_Testing.ipynb to rst
# [NbConvertApp] Writing 800 bytes to Unit_Testing.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Minimal Example PySD with EMA.ipynb to rst
# [NbConvertApp] Support files will be in Minimal Example PySD with EMA_files/
# [NbConvertApp] Making directory Minimal Example PySD with EMA_files
# [NbConvertApp] Making directory Minimal Example PySD with EMA_files
# [NbConvertApp] Making directory Minimal Example PySD with EMA_files
# [NbConvertApp] Writing 6616 bytes to Minimal Example PySD with EMA.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Baby_Name_Data.ipynb to rst
# [NbConvertApp] Writing 943 bytes to Baby_Name_Data.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook US_Census_Data_Collection.ipynb to rst
# [NbConvertApp] Writing 54172 bytes to US_Census_Data_Collection.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook sources.ipynb to rst
# [NbConvertApp] Writing 631 bytes to sources.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Manufacturing_Defects_Synthetic.ipynb to rst
# [NbConvertApp] Writing 1993 bytes to Manufacturing_Defects_Synthetic.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Ebola_Data_Loader.ipynb to rst
# [NbConvertApp] Support files will be in Ebola_Data_Loader_files/
# [NbConvertApp] Making directory Ebola_Data_Loader_files
# [NbConvertApp] Writing 7266 bytes to Ebola_Data_Loader.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Email_Data_Formatter.ipynb to rst
# [NbConvertApp] Support files will be in Email_Data_Formatter_files/
# [NbConvertApp] Making directory Email_Data_Formatter_files
# [NbConvertApp] Writing 8080 bytes to Email_Data_Formatter.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Town_Formatter.ipynb to rst
# [NbConvertApp] Writing 7835 bytes to Town_Formatter.rst
#
#
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook Prepare Data.ipynb to rst
# [NbConvertApp] Support files will be in Prepare Data_files/
# [NbConvertApp] Making directory Prepare Data_files
# [NbConvertApp] Writing 16822 bytes to Prepare Data.rst
