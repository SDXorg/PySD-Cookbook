# %%
import pysd

# %%
model = pysd.read_vensim('../../models/Subscripted_Population/Subscripted Population Model.mdl')
model.run()
# Out:
#   File "../../models/Subscripted_Population/Subscripted Population Model.py", line 19
# ...
